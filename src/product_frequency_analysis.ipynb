# %%
from database_handler import just_order_items
import matplotlib.pyplot as plt
import collections
order_items =  just_order_items()
items_frequency = collections.Counter(order_items)
plt.pie(items_frequency.values(), labels = items_frequency.keys())
# Out:
# (('P001',), ('P001',), ('P001',), ('P001',), ('P001',), ('P002',))
# ([<matplotlib.patches.Wedge at 0x25de11699a0>,
#   <matplotlib.patches.Wedge at 0x25de11698e0>],
#  [Text(-0.9526279098330698, 0.5500000594609756, "('P001',)"),
#   Text(0.9526278840857078, -0.5500001040567061, "('P002',)")])
