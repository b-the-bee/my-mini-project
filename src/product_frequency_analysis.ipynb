# %%
from database_handler import just_order_items, get_item_names
import matplotlib.pyplot as plt
import collections
order_items =  just_order_items()
items_frequency = collections.Counter(order_items)
item_name_dict = get_item_names()
order_items_names = [item_name_dict[item_id] for item_id in order_items]
names_frequency = collections.Counter(order_items_names)
plt.pie(items_frequency.values(), labels = names_frequency.keys())
# Out:
# ([<matplotlib.patches.Wedge at 0x20ef8c3e3f0>,
#   <matplotlib.patches.Wedge at 0x20ef8817f50>,
#   <matplotlib.patches.Wedge at 0x20ef8c76930>,
#   <matplotlib.patches.Wedge at 0x20ef8c76db0>,
#   <matplotlib.patches.Wedge at 0x20ef8c771d0>,
#   <matplotlib.patches.Wedge at 0x20ef8c77650>,
#   <matplotlib.patches.Wedge at 0x20ef8c77a40>,
#   <matplotlib.patches.Wedge at 0x20ef8c77e90>,
#   <matplotlib.patches.Wedge at 0x20ef8cb8350>,
#   <matplotlib.patches.Wedge at 0x20ef8cb87d0>],
#  [Text(0.6016430102375327, 0.9208831023709363, 'White Americano'),
#   Text(-0.868054493749272, 0.6756340695092983, ' Iced Americano'),
#   Text(-1.0403990151515934, -0.3571692725747761, ' Black Americano'),
#   Text(-0.6016431180116518, -0.920883031958575, ' Iced Cappuccino'),
#   Text(-0.27003420006208584, -1.066340250950338, 'Cappuccino'),
#   Text(0.09083711390859571, -1.0962429560716718, 'Mocha'),
#   Text(0.4418648169588925, -1.007350725186558, 'Latte'),
#   Text(0.7450096101456386, -0.8092964109587065, 'Iced Cortado'),
#   Text(0.9674210508658966, -0.5235422717809181, 'Cortado'),
#   Text(1.0849974080926825, -0.1810542030226344, 'Frappe')])
